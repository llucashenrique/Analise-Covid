# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import nbformat
import plotly.express as px
sns.set(style="darkgrid")
sns.set_theme(style="whitegrid", context="talk")
# Out:
# mkdir -p failed for path /home/lucas/.config/matplotlib: [Errno 13] Permission denied: '/home/lucas/.config/matplotlib'
# Matplotlib created a temporary cache directory at /tmp/matplotlib-zh4v1m3k because there was an issue with the default path (/home/lucas/.config/matplotlib); it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
plt.plot([1, 2, 3], [4, 5, 6])

# %%
df_raw = pd.read_csv("../data/raw/lightning.csv")
df_raw.head(1)
# Out:
#                   time        lat        lon  region    mds  mcg  status
# 0  1764012614591744000  33.293266 -94.548227       1  14198  162      31

# %%
sns.jointplot(data=df_raw, x="lat", y="lon", kind="hex", cmap="magma")  # kind: "scatter", "kde", "hex"

# %%
data = {
    'Year': [2018, 2019, 2020, 2021, 2022],
    'Sales': [100, 120, 90, 150, 180],
    'Region': ['East', 'West', 'East', 'West', 'East']
}
df = pd.DataFrame(data)

# %%
# Create a scatter plot
fig = px.scatter(df, x='Year', y='Sales', color='Region', title='Sales Performance by Year and Region')

# Create a bar chart
# fig = px.bar(df, x='Year', y='Sales', title='Annual Sales')

# %%
fig.show()
